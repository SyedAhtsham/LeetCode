# %%
# nums = [7,4,3,9,1,8,5,2,6]
#         0     1     2     3     4     5     6     7
nums = [40527,53696,10730,66491,62141,83909,78635,18560]
k=2

arr = []

i = 0
index = 0
size = len(nums)
upper = size - k
sum = 0
m = 0

divideBy = k*2+1




if size == 1 and k==0:
    arr.append(nums[0])
#     return arr
if size == 1 and k>0:
    arr.append(-1)
#     return arr
    
# if k == 0:
    
#     return nums

for num in nums:
    sum += num

    if i<k:
        arr.append(-1)
        i+=1
        continue
        
    if i >= k*2:
        arr.append(int(sum/divideBy))
        sum = sum-nums[m]
        m += 1
    print(i)
    i += 1
    
    
n = upper


while n!= size:
    arr.append(-1)
    n+=1
    
# return arr

print(arr)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# [-1, -1, 46717, 55393, 60381, 61947, -1, -1]

# %% [markdown]
# You are given an array prices where prices[i] is the price of a given stock on the ith day.
#
# You want to maximize your profit by choosing a single day to buy one stock and choosing a different day in the future to sell that stock.
#
# Return the maximum profit you can achieve from this transaction. If you cannot achieve any profit, return 0.
#
#
#
# Example 1:
#
# Input: prices = [7,1,5,3,6,4]
# Output: 5
# Explanation: Buy on day 2 (price = 1) and sell on day 5 (price = 6), profit = 6-1 = 5.
# Note that buying on day 2 and selling on day 1 is not allowed because you must buy before you sell.
# Example 2:
#
# Input: prices = [7,6,4,3,1]
# Output: 0
# Explanation: In this case, no transactions are done and the max profit = 0.

# %%
import copy

# prices = [7,1,5,3,6,4]
# prices = [1,2]
# prices = [2,4,1]

prices = [11,4,7,1,2]


def profit(prices):
    
    maxVal = max(prices)
    maxInd = prices.index(maxVal)
    if maxInd == 0:
        prices.remove(maxVal)

    prices2 = copy.deepcopy(prices)
    prices3 = copy.deepcopy(prices)
    minVal = min(prices)
    minInd = prices.index(minVal)

    maxVal = max(prices)
    maxInd = prices.index(maxVal)
    prf1 = 0
    prf2 = 0
    prf3 = 0


    if minInd < maxInd:
        return maxVal-minVal





    while(minInd > maxInd):
        minVal = min(prices)
        minInd = prices.index(minVal)

        maxVal = max(prices)
        maxInd = prices.index(maxVal)

        print(minInd, maxInd)
        print(minVal, maxVal)
        print()
        if minInd < maxInd:
            prf1 = maxVal-minVal
        else:
            prices.remove(maxVal)


    minVal = min(prices2)
    minInd = prices2.index(minVal)

    maxVal = max(prices2)
    maxInd = prices2.index(maxVal)


    while(minInd > maxInd):
        minVal = min(prices2)
        minInd = prices2.index(minVal)

        maxVal = max(prices2)
        maxInd = prices2.index(maxVal)

        print(minInd, maxInd)
        print(minVal, maxVal)
        print()
        if minInd < maxInd:
            prf2 = maxVal-minVal
        else:
            prices2.remove(minVal)

    minVal = min(prices3)
    minInd = prices3.index(minVal)

    maxVal = max(prices3)
    maxInd = prices3.index(maxVal)
    while(minInd > maxInd):
        if len(prices) == 1:
            prf3 = tempMax - prices[0]
            break
        if len(prices3) == 0:
            break
        minVal = min(prices3)
        minInd = prices3.index(minVal)

        maxVal = max(prices3)
        maxInd = prices3.index(maxVal)

        print(minInd, maxInd)
        print(minVal, maxVal)
        print()
        if minInd < maxInd:
            prf3 = maxVal-minVal
        else:
            if maxVal in prices3:
                tempMax = maxVal
                prices3.remove(maxVal)
            if minVal in prices3:

                prices3.remove(minVal)

    print(prf2)
    return max(prf1, prf2, prf3) 



profit(prices)
# Out:
# 2 1
# 1 7
#
# 1 0
# 1 4
#
# 0 1
# 1 2
#
# 2 1
# 1 7
#
# 2 1
# 2 7
#
# 0 1
# 4 7
#
# 2 1
# 1 7
#
# 1 0
# 2 4
#
# 3
# 3

# %%
nums = [9,6,4,2,3,5,7,0,1]

mySet = set(nums)
length = len(nums)
for i in range(length):
    if i not in mySet:
        break

print(i)
# Out:
# 8

# %%
arr = [1,2,3]
